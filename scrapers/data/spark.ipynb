# %%
import os
import glob
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("RecursiveCSVLoader").getOrCreate()

data_dir = "./" 
csv_files = glob.glob(os.path.join(data_dir, "**", "*.csv"), recursive=True)
json_files = glob.glob(os.path.join(data_dir, "**", "*.json"), recursive=True)

dfs = {}
for file_path in csv_files:
    file_name = os.path.splitext(os.path.basename(file_path))[0]
    dfs[file_name] = spark.read.option("header", True).option("inferSchema", True).csv(file_path)

for file_path in json_files:
    relative_path = os.path.relpath(file_path, data_dir)
    key_name = relative_path.replace("/", "_").replace(".json", "")
    dfs[key_name] = spark.read.option("multiline", True).json(file_path)



for name in dfs:
    print(f"Loaded: {name}")
# Out:
# Loaded: google_trends__2025-05-13
# Loaded: google_trends__2025-05-14
# Loaded: google_trends__2025-05-15
# Loaded: google_trends__2025-05-16
# Loaded: google_trends__2025-05-17
# Loaded: google_trends__2025-05-18
# Loaded: google_trends__2025-05-19
# Loaded: google_trends__2025-05-20
# Loaded: google_trends__2025-05-21
# Loaded: google_trends__2025-05-22
# Loaded: google_trends__2025-05-23
# Loaded: google_trends__2025-05-24
# Loaded: google_trends__2025-05-25
# Loaded: google_trends__2025-05-26
# Loaded: google_trends__2025-05-27
# Loaded: google_trends__2025-05-28
# Loaded: google_trends__2025-05-29
# Loaded: google_trends__2025-05-30
# Loaded: google_trends__2025-05-31
# Loaded: google_trends__2025-06-01
# Loaded: google_trends__2025-06-02
# Loaded: google_trends__2025-06-03
# Loaded: google_trends__2025-06-04
# Loaded: google_trends__2025-06-05
# Loaded: google_trends__2025-06-06
# Loaded: google_trends__2025-06-07
# Loaded: google_trends__2025-06-08
# Loaded: google_trends__2025-06-09
# Loaded: google_trends__2025-06-10
# Loaded: google_trends__2025-06-11
# Loaded: google_trends__2025-06-12
# Loaded: google_trends__2025-06-13
# Loaded: polls_data
# Loaded: polls_kandydaci
# Loaded: followers3
# Loaded: twitter\tweets_2025-06-11
# Loaded: twitter\tweets_2025-06-12

# %%
for name, df in dfs.items():
    print()
    print()
    print(100*"=")
    print()
    print()
    print(f"New file: {name}")
    df.printSchema()
    df.show(1)
# Out:
# ====================================================================================================
#
#
# New file: google_trends__2025-05-13
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-13|                    96|                  12|          30|   30|          0|            68|               80|              51|             42|              31|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-14
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-14|                    81|                  10|          37|   24|          7|            53|               55|              46|             36|              23|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-15
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-15|                    84|                  11|          39|   28|          7|            60|               59|              50|             41|              22|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-16
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-16|                   100|                  17|          49|   29|          5|            75|               83|              64|             70|              35|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-17
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-17|                    88|                   9|          39|   27|          0|            60|               59|              63|             63|              30|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-18
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-18|                   100|                  13|          58|   23|          4|           100|               90|              74|             49|              25|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-19
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-19|                    66|                  11|          54|   22|          2|            72|               70|              43|             17|               7|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-20
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-20|                    49|                   7|          27|   13|          0|            35|               34|              41|              8|               3|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-21
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-21|                    60|                   6|          20|    6|          0|            32|               26|              23|              5|               2|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-22
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-22|                    50|                   5|          19|    8|          0|            76|               36|              55|              4|               1|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-23
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-23|                    54|                   5|          17|    7|          0|           100|               78|              29|              4|               1|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-24
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-24|                    43|                   5|          19|    6|          2|            84|              100|              77|              2|               1|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-25
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-25|                    57|                   7|          32|    6|          0|            56|               65|              44|              3|               1|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-26
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-26|                    47|                   4|          23|    6|          0|            60|               29|              21|              2|               1|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-27
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-27|                    50|                   4|          17|    2|          0|            48|               23|              10|              1|               1|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-28
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-28|                    44|                   5|          17|    3|          0|            34|               23|              18|              1|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-29
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-29|                    48|                   5|          16|    4|          0|            32|               24|              10|              2|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-30
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-30|                    54|                   5|          13|    4|          1|            37|               35|               7|              2|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-05-31
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-31|                    40|                   3|          10|    3|          1|            24|               24|               4|              1|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-06-01
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-06-01|                   100|                   9|          17|    4|          1|           100|               99|               8|              2|               1|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-06-02
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-06-02|                   100|                  10|          24|    8|          1|           100|               36|               5|              1|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-06-03
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-06-03|                    46|                   6|          22|   11|          1|            28|               11|               2|              1|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-06-04
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-06-04|                    34|                   4|          18|    6|          1|            17|                6|               3|              1|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-06-05
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-06-05|                    26|                   3|          11|    4|          1|            11|                4|               1|              1|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-06-06
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-06-06|                    23|                   3|           9|    3|          0|             9|                3|               1|              0|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-06-07
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-06-07|                    21|                   3|           7|    2|          0|             6|                3|               1|              0|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-06-08
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-06-08|                    26|                   3|           7|    2|          1|             6|                3|               1|              0|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-06-09
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-06-09|                    18|                   2|           6|    3|          1|             4|                2|               1|              0|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-06-10
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-06-10|                    16|                   2|           7|    4|          0|             3|                1|               1|              0|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-06-11
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-06-11|                    29|                   4|          11|    8|          1|             4|                1|               1|              1|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-06-12
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-06-12|                    18|                   2|           7|    4|          0|             3|                1|               1|              0|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: google_trends__2025-06-13
# root
#  |-- date: date (nullable = true)
#  |-- Prawo i Sprawiedliwość: integer (nullable = true)
#  |-- Koalicja Obywatelska: integer (nullable = true)
#  |-- Konfederacja: integer (nullable = true)
#  |-- Razem: integer (nullable = true)
#  |-- Nowa Lewica: integer (nullable = true)
#  |-- Karol Nawrocki: integer (nullable = true)
#  |-- Rafał Trzaskowski: integer (nullable = true)
#  |-- Sławomir Mentzen: integer (nullable = true)
#  |-- Adrian Zandberg: integer (nullable = true)
#  |-- Magdalena Biejat: integer (nullable = true)
#
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |      date|Prawo i Sprawiedliwość|Koalicja Obywatelska|Konfederacja|Razem|Nowa Lewica|Karol Nawrocki|Rafał Trzaskowski|Sławomir Mentzen|Adrian Zandberg|Magdalena Biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-06-13|                    16|                   1|           5|    2|          0|             2|                1|               1|              0|               0|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
#
#
#
# ====================================================================================================
#
#
# New file: polls_data
# root
#  |-- Data: date (nullable = true)
#  |-- Publikator: string (nullable = true)
#  |-- Liczność: string (nullable = true)
#  |-- RazemRaz.: double (nullable = true)
#  |-- LewicaLew.: double (nullable = true)
#  |-- KO: double (nullable = true)
#  |-- TD: double (nullable = true)
#  |-- PiS: double (nullable = true)
#  |-- KonfederacjaKon.: double (nullable = true)
#
# +----------+-------------------+--------+---------+----------+----+---+----+----------------+
# |      Data|         Publikator|Liczność|RazemRaz.|LewicaLew.|  KO| TD| PiS|KonfederacjaKon.|
# +----------+-------------------+--------+---------+----------+----+---+----+----------------+
# |2025-06-08|United Surveys / WP|  1000.0|      5.2|       6.0|33.0|5.5|32.0|            16.0|
# +----------+-------------------+--------+---------+----------+----+---+----+----------------+
# only showing top 1 row
#
#
# ====================================================================================================
#
#
# New file: polls_kandydaci
# root
#  |-- Institute: string (nullable = true)
#  |-- Sample: double (nullable = true)
#  |-- Date: date (nullable = true)
#  |-- Trzaskowski: double (nullable = true)
#  |-- Nawrocki: double (nullable = true)
#  |-- NZ/BU: double (nullable = true)
#  |-- Przewaga: double (nullable = true)
#
# +--------------+------+----------+-----------+--------+-----+--------+
# |     Institute|Sample|      Date|Trzaskowski|Nawrocki|NZ/BU|Przewaga|
# +--------------+------+----------+-----------+--------+-----+--------+
# |United Surveys|2596.0|2025-05-27|       47.6|    47.4|  5.0|     0.2|
# +--------------+------+----------+-----------+--------+-----+--------+
# only showing top 1 row
#
#
# ====================================================================================================
#
#
# New file: followers3
# root
#  |-- Partia: string (nullable = true)
#  |-- Portal: string (nullable = true)
#  |-- Followers: string (nullable = true)
#
# +--------------------+--------+---------+
# |              Partia|  Portal|Followers|
# +--------------------+--------+---------+
# |Prawo i Sprawiedl...|facebook|   436000|
# +--------------------+--------+---------+
# only showing top 1 row
#
#
# ====================================================================================================
#
#
# New file: twitter\tweets_2025-06-11
# root
#  |-- author: string (nullable = true)
#  |-- handle: string (nullable = true)
#  |-- likes: long (nullable = true)
#  |-- replies: long (nullable = true)
#  |-- retweets: long (nullable = true)
#  |-- scraped_at: string (nullable = true)
#  |-- search_term: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- tweet_url: string (nullable = true)
#
# +--------------+-------+-----+-------+--------+--------------------+-----------+--------------------+--------------------+--------------------+
# |        author| handle|likes|replies|retweets|          scraped_at|search_term|                text|           timestamp|           tweet_url|
# +--------------+-------+-----+-------+--------+--------------------+-----------+--------------------+--------------------+--------------------+
# |Roman Milewski|romil63|    0|      0|       0|2025-06-13T13:39:...|        PiS|Dostali pieniądze...|2025-06-11T23:59:...|https://x.com/rom...|
# +--------------+-------+-----+-------+--------+--------------------+-----------+--------------------+--------------------+--------------------+
# only showing top 1 row
#
#
# ====================================================================================================
#
#
# New file: twitter\tweets_2025-06-12
# root
#  |-- author: string (nullable = true)
#  |-- handle: string (nullable = true)
#  |-- likes: long (nullable = true)
#  |-- replies: long (nullable = true)
#  |-- retweets: long (nullable = true)
#  |-- scraped_at: string (nullable = true)
#  |-- search_term: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- tweet_url: string (nullable = true)
#
# +-----------+------------+-----+-------+--------+--------------------+-----------+--------------------+--------------------+--------------------+
# |     author|      handle|likes|replies|retweets|          scraped_at|search_term|                text|           timestamp|           tweet_url|
# +-----------+------------+-----+-------+--------+--------------------+-----------+--------------------+--------------------+--------------------+
# |Pigeoniasty|PigeonPiecyk|    1|      0|       0|2025-06-13T13:22:...|        PiS|Właśnie na tym, ż...|2025-06-12T23:59:...|https://x.com/Pig...|
# +-----------+------------+-----+-------+--------+--------------------+-----------+--------------------+--------------------+--------------------+
# only showing top 1 row

# %%
from pyspark.sql.functions import col

def normalize_column_names(df):
    for col_name in df.columns:
        df = df.withColumnRenamed(col_name, col_name.strip().lower().replace(" ", "_").replace(".", "").replace("/", "_"))
    return df

dfs = {name: normalize_column_names(df) for name, df in dfs.items()}

# %%
from functools import reduce

trend_dfs = [df for name, df in dfs.items() if name.startswith("google_trends__")]
combined_trends_df = reduce(lambda a, b: a.unionByName(b), trend_dfs)

combined_trends_df = combined_trends_df.withColumnRenamed("date", "trend_date")
combined_trends_df.show(3)
# Out:
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |trend_date|prawo_i_sprawiedliwość|koalicja_obywatelska|konfederacja|razem|nowa_lewica|karol_nawrocki|rafał_trzaskowski|sławomir_mentzen|adrian_zandberg|magdalena_biejat|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# |2025-05-13|                    96|                  12|          30|   30|          0|            68|               80|              51|             42|              31|
# |2025-05-14|                    81|                  10|          37|   24|          7|            53|               55|              46|             36|              23|
# |2025-05-15|                    84|                  11|          39|   28|          7|            60|               59|              50|             41|              22|
# +----------+----------------------+--------------------+------------+-----+-----------+--------------+-----------------+----------------+---------------+----------------+
# only showing top 3 rows

# %%
polls_data = dfs.get("polls_data")
polls_kandydaci = dfs.get("polls_kandydaci")

# Ensure dates are standardized
polls_data = polls_data.withColumnRenamed("data", "poll_date")
polls_kandydaci = polls_kandydaci.withColumnRenamed("date", "poll_date")

print(polls_kandydaci)
# Out:
# DataFrame[institute: string, sample: double, poll_date: date, trzaskowski: double, nawrocki: double, nz_bu: double, przewaga: double]

# %%
followers_df = dfs.get("followers3")
followers_df.show()
# Out:
# +--------------------+---------+-----------+
# |              partia|   portal|  followers|
# +--------------------+---------+-----------+
# |Prawo i Sprawiedl...| facebook|     436000|
# |Koalicja Obywatelska| facebook|     407000|
# |        Konfederacja| facebook|     887000|
# |               Razem| facebook|     176000|
# |         Nowa Lewica| facebook|     162000|
# |Prawo i Sprawiedl...|instagram|      46117|
# |Koalicja Obywatelska|instagram|     107093|
# |        Konfederacja|instagram|     232303|
# |               Razem|instagram|     107507|
# |         Nowa Lewica|instagram|      80060|
# |Prawo i Sprawiedl...|  twitter|Brak danych|
# |Koalicja Obywatelska|  twitter|Brak danych|
# |        Konfederacja|  twitter|Brak danych|
# |               Razem|  twitter|Brak danych|
# |         Nowa Lewica|  twitter|Brak danych|
# |Prawo i Sprawiedl...|  youtube|Brak danych|
# |Koalicja Obywatelska|  youtube|Brak danych|
# |        Konfederacja|  youtube|Brak danych|
# |               Razem|  youtube|Brak danych|
# |         Nowa Lewica|  youtube|Brak danych|
# +--------------------+---------+-----------+
# only showing top 20 rows
